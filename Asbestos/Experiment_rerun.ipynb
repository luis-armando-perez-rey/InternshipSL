# %%
from DataAsbestos import DataAsbestos
from AsbestosNetwork import AsbestosNetwork
from Asbestos_Utils import load_image
import cv2
from os.path import join,exists
# Out:
# Using TensorFlow backend.

# %%
path_data = "./Test data"
DA_parameters = {'path_name':path_data,
                 'data_name':'Testing',
                 'size':128,
                 'data_augmentation':False,
                 'train_percentage':0.7,
                 'val_percentage':0.1,
                 'test_percentage':0.2,
                 'file_type_load':'.jpg',
                 'removal':True}
DA = DataAsbestos(**DA_parameters)
# Out:
# Size of training set: 7
#
# Size of validation set: 1
#
# Size of test set: 2
#
# Creating the cropped data ...
#
# Total of training crops created = 37
#
# Total of validation crops created = 64
#
# Total of test crops created = 128
#
# Finished loading data

# %%
from AsbestosHardExamples import AsbestosHardExamples
from keras.optimizers import Adam
from AsbestosNetwork import jaccard_coef,dice_coef
path_data = "./Test data"
AHE_parameters = {'path_name':path_data,
                        'size':128,
                        'data_name':'Testing',
                        'channels': 1,
                        'classes': 2,
                        'num_layers': 1,
                        'loss': "binary_crossentropy",
                        'optimizer': Adam(),
                        'data_augmentation':False,
                        'train_percentage':0.7,
                        'val_percentage':0.1,
                        'test_percentage':0.2,
                        'remove':True,
                        'data_type':'.tiff',
                        'batch_normalization':True,
                        'dropout_type':1,
                        'dropout_p':0.5}
AHE = AsbestosHardExamples(**AHE_parameters)
# Out:
# The data set already exists. Loading the specified data ...
#
# Cropped data already exists. Obtaining the names from the cropped images
# Total of training crops = 37
#
# Total of validation crops = 64
#
# Total of test crops = 64
#
# [<tf.Tensor 'input_1:0' shape=(?, ?, ?, 1) dtype=float32>, <tf.Tensor 'spatial_dropout2d_1/cond/Merge:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'conv2d_3/Sigmoid:0' shape=(?, ?, ?, 1) dtype=float32>]

# %%
AHE_train_parameters = {'prefix_log':'Whatever',
                        'HE_per_image':2,
                        'batch_size_train': 2,
                        'batch_size_val':10,
                        'epochs_per_training':10,
                        'hard_example_epochs':2}
AHE.hard_example_training(**AHE_train_parameters)
# Out:
# 2
# Parameters of the model are:
#
# Layers :: 1
#
# Size training batch :: 2
#
# Size validation batch :: 10
#
# Epochs :: 10
#
# Input size :: 128
#
# Modified data :: 0
#
# The tensorboard logfiles will be saved in C:\Users\Luis Pérez\Documents\Master\TUE\Internship Sioux\Python\Final Training\Asbestos/Testing/TensorBoard/Whatever/ L 1 BT 2 BV 10 E 10 D 37 MD 0 S 128 HEE 2 HEPI 2 BN 1 DPT 1 DPP 50...
#
# Train data used = 37
#
# Validation data used = 64
#
# Epoch 1/10
# 18/18 [==============================] - 12s 669ms/step - loss: 0.9223 - jaccard_coef: 0.4942 - dice_coef: 0.6611 - val_loss: 0.4065 - val_jaccard_coef: 0.6874 - val_dice_coef: 0.8147
# Epoch 2/10
# 18/18 [==============================] - 11s 627ms/step - loss: 0.8153 - jaccard_coef: 0.5315 - dice_coef: 0.6938 - val_loss: 1.1704 - val_jaccard_coef: 0.3280 - val_dice_coef: 0.4940
# Epoch 3/10
# ...

# %%
AHE.UNETnet.model

# %%
from keras.optimizers import Adam
from AsbestosNetwork import jaccard_coef,dice_coef
AN_parameters = {'DataAsbestosObj': DA,
                        'channels': 1,
                        'classes': 2,
                        'initial_features': 32,
                        'num_layers': 1,
                        'loss': "binary_crossentropy",
                        'optimizer': Adam(),
                        'metrics':[jaccard_coef,dice_coef],
                        'data_type':'.tiff',
                        'batch_normalization':True,
                        'dropout_type':0,
                        'dropout_p':1.0}
AN = AsbestosNetwork(**AN_parameters)
# Out:
# [<tf.Tensor 'input_1:0' shape=(?, ?, ?, 1) dtype=float32>, <tf.Tensor 'batch_normalization_2/cond/Merge:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'conv2d_3/Sigmoid:0' shape=(?, ?, ?, 1) dtype=float32>]

# %%
train_parameters = {'prefix_log':'First_Stage',
                    'batch_size_train':10,
                    'batch_size_val':10,
                    'epochs':200}
AN.train_model(**train_parameters)
# Out:
# Parameters of the model are:
#
# Layers :: 1
#
# Size training batch :: 10
#
# Size validation batch :: 10
#
# Epochs :: 100
#
# Input size :: 128
#
# Modified data :: 1
#
# The tensorboard logfiles will be saved in C:\Users\Luis Pérez\Documents\Master\TUE\Internship Sioux\Python\Final Training\Asbestos/Final_Report/TensorBoard/First_Stage/ L 1 BT 10 BV 10 E 100 D 1464 MD 1 S 128 HEE 0 HEPI 0 BN 1 DPT 0 DPP 100...
#
# Train data used = 1464
#
# Validation data used = 448
#
# Epoch 1/100
# 146/146 [==============================] - 374s 3s/step - loss: 0.4575 - jaccard_coef: 0.6473 - dice_coef: 0.7823 - val_loss: 0.2593 - val_jaccard_coef: 0.7763 - val_dice_coef: 0.8741
# Epoch 2/100
# 146/146 [==============================] - 374s 3s/step - loss: 0.1446 - jaccard_coef: 0.8819 - dice_coef: 0.9368 - val_loss: 0.0809 - val_jaccard_coef: 0.9258 - val_dice_coef: 0.9615
# Epoch 3/100
# ...

# %%
from Statistics import AsbestosModelProcess
path_data, path_data_files, model, model_name, threshold, percentage, data='Validation'
AMP_parameters = {'path_data':path_data,
                  'path_data_files':'./Final_Report',
                  'model': AN.model,
                  'model_name':AN.model_name,
                  'threshold':0.2,
                  'percentage':0.1,
                  'data':'Test'}
AMP = AsbestosModelProcess(**AMP_parameters)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-6d3fcfa474e4> in <module>()
# ----> 1 from AsbestosPostProcessProcess import AsbestosModelProcess
#       2 path_data, path_data_files, model, model_name, threshold, percentage, data='Validation'
#       3 AMP_parameters = {'path_data':path_data,
#       4                   'path_data_files':'./Final_Report',
#       5                   'model': AN.model,
#
# ImportError: No module named 'AsbestosPostProcessProcess'

# %%
# %reset -f

# %% [markdown]
# # Looping models

# %%
for layers in range(2,6):
    from DataAsbestos import DataAsbestos
    from AsbestosNetwork import AsbestosNetwork
    from Asbestos_Utils import load_image
    import cv2
    from os.path import join,exists
    ## DATA GENERATION
    path_data = "./Complete Data Set"
    DA_parameters = {'path_name':path_data,
                     'data_name':'Final_Report',
                     'size':128,
                     'data_augmentation':True,
                     'train_percentage':0.63,
                     'val_percentage':0.07,
                     'test_percentage':0.3,
                     'file_type_load':'.jpg',
                     'removal':True}
    DA = DataAsbestos(**DA_parameters)

    from keras.optimizers import Adam
    from AsbestosNetwork import jaccard_coef,dice_coef
    AN_parameters = {'DataAsbestosObj': DA,
                            'channels': 1,
                            'classes': 2,
                            'initial_features': 32,
                            'num_layers': layers,
                            'loss': "binary_crossentropy",
                            'optimizer': Adam(),
                            'metrics':[jaccard_coef,dice_coef],
                            'data_type':'.tiff',
                            'batch_normalization':True,
                            'dropout_type':0,
                            'dropout_p':1.0}
    AN = AsbestosNetwork(**AN_parameters)

    train_parameters = {'prefix_log':'First_Stage',
                        'batch_size_train':10,
                        'batch_size_val':10,
                        'epochs':150}
    AN.train_model(**train_parameters)
    from UNET_Model import UNET
    UNET_parameters = {'channels': 1,
                            'classes': 2,
                            'initial_features': 32,
                            'num_layers': layers,
                            'loss': "binary_crossentropy",
                            'optimizer': Adam(),
                            'metrics':[jaccard_coef,dice_coef],
                            'batch_normalization':True,
                            'dropout_type':0,
                            'dropout_p':1.0}
    model = UNET(**UNET_parameters)
    from Statistics import AsbestosModelProcess
    path_data, path_data_files, model, model_name, threshold, percentage, data='Validation'
    AMP_parameters = {'path_data':path_data,
                      'path_data_files':'./Final_Report',
                      'model': AN.model,
                      'model_name':AN.model_name,
                      'threshold':0.2,
                      'percentage':0.1,
                      'data':'Test'}
    AMP = AsbestosModelProcess(**AMP_parameters)
    # %reset -f
    for p_drop in [0.2,0.3,0.4,0.5]:
        from DataAsbestos import DataAsbestos
        from AsbestosNetwork import AsbestosNetwork
        from Asbestos_Utils import load_image
        import cv2
        from os.path import join,exists
        ## DATA GENERATION
        path_data = "./Complete Data Set"
        DA_parameters = {'path_name':path_data,
                         'data_name':'Final_Report',
                         'size':128,
                         'data_augmentation':True,
                         'train_percentage':0.63,
                         'val_percentage':0.07,
                         'test_percentage':0.3,
                         'file_type_load':'.jpg',
                         'removal':True}
        DA = DataAsbestos(**DA_parameters)

        from keras.optimizers import Adam
        from AsbestosNetwork import jaccard_coef,dice_coef
        AN_parameters = {'DataAsbestosObj': DA,
                                'channels': 1,
                                'classes': 2,
                                'initial_features': 32,
                                'num_layers': layers,
                                'loss': "binary_crossentropy",
                                'optimizer': Adam(),
                                'metrics':[jaccard_coef,dice_coef],
                                'data_type':'.tiff',
                                'batch_normalization':True,
                                'dropout_type':2,
                                'dropout_p':p_drop}
        AN = AsbestosNetwork(**AN_parameters)
        prefix_log = 'First_Stage'
        train_parameters = {'prefix_log':prefix_log,
                            'batch_size_train':10,
                            'batch_size_val':10,
                            'epochs':150}
        AN.train_model(**train_parameters)
        from UNET_Model import UNET
        UNET_parameters = {'channels': 1,
                            'classes': 2,
                            'initial_features': 32,
                            'num_layers': layers,
                            'loss': "binary_crossentropy",
                            'optimizer': Adam(),
                            'metrics':[jaccard_coef,dice_coef],
                            'batch_normalization':True,
                            'dropout_type':0,
                            'dropout_p':1.0}
        model = UNET(**UNET_parameters)
        parameter_string = ' L ' + str(layers) + ' BT ' + str() + ' BV ' + str(self.params['BV'])+' E ' + str(self.params['E']) +' D '+ str(len(self.train_names)) + ' MD ' + str(self.params['MD']) + ' S ' + str(self.params['S']) + ' HEE '+ str(self.params['HEE'])+ ' HEPI '+str(self.params['HEPI']) + ' BN ' + str(self.params['BN']) + ' DPT '+str(self.params['DPT'])+' DPP '+str(self.params['DPP'])
        model.load_weights('./' + self.data_name + '/' + prefix_log.replace('/', '')+ ' BEST ' + parameter_string+ ' .h5')
        from Statistics import AsbestosModelProcess
        path_data, path_data_files, model, model_name, threshold, percentage, data='Validation'
        AMP_parameters = {'path_data':path_data,
                          'path_data_files':'./Final_Report',
                          'model': AN.model,
                          'model_name':AN.model_name,
                          'threshold':0.2,
                          'percentage':0.1,
                          'data':'Test'}
        AMP = AsbestosModelProcess(**AMP_parameters)
        # %reset -f
