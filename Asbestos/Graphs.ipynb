# %% [markdown]
# # Analysis of models

# %%
import numpy as np
from AsbestosModels import AsbestosModels
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
AM = AsbestosModels('./Final_Report/Models')
# Out:
# Model number 0 : First_Stage BEST   : parameters {'BV': 10, 'BT': 10, 'HEE': 0, 'L': 1, 'MD': 1, 'DPT': 0, 'S': 128, 'DPP': 100, 'HEPI': 0, 'D': 1440, 'BN': 1, 'E': 200}
# Model number 1 : First_Stage BEST   : parameters {'BV': 10, 'BT': 10, 'HEE': 0, 'L': 2, 'MD': 1, 'DPT': 0, 'S': 128, 'DPP': 100, 'HEPI': 0, 'D': 1440, 'BN': 1, 'E': 100}
# Model number 2 : First_Stage BEST   : parameters {'BV': 10, 'BT': 10, 'HEE': 0, 'L': 2, 'MD': 1, 'DPT': 0, 'S': 128, 'DPP': 100, 'HEPI': 0, 'D': 1440, 'BN': 1, 'E': 150}
# Model number 3 : First_Stage BEST   : parameters {'BV': 10, 'BT': 10, 'HEE': 0, 'L': 3, 'MD': 1, 'DPT': 0, 'S': 128, 'DPP': 100, 'HEPI': 0, 'D': 1440, 'BN': 0, 'E': 100}
# Model number 4 : First_Stage BEST   : parameters {'BV': 10, 'BT': 10, 'HEE': 0, 'L': 3, 'MD': 1, 'DPT': 1, 'S': 128, 'DPP': 50, 'HEPI': 0, 'D': 1440, 'BN': 0, 'E': 100}
# ...

# %%
saved_averages=[]
percentage = 0.2
for num_model in range(len(AM.models)):
    model,model_name = AM.extract_model(num_model,1)
    saved_averages.append(np.load('./Numpy Variables/'+'Validation data '+'Percentage'+str(percentage).replace('.','_')+model_name+'.npy'))
# Out:
# [<tf.Tensor 'input_1:0' shape=(?, ?, ?, 1) dtype=float32>, <tf.Tensor 'batch_normalization_2/cond/Merge:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'conv2d_3/Sigmoid:0' shape=(?, ?, ?, 1) dtype=float32>]
# [<tf.Tensor 'input_2:0' shape=(?, ?, ?, 1) dtype=float32>, <tf.Tensor 'batch_normalization_4/cond/Merge:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'max_pooling2d_1/MaxPool:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'batch_normalization_6/cond/Merge:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'concatenate_1/concat:0' shape=(?, ?, ?, 96) dtype=float32>, <tf.Tensor 'batch_normalization_8/cond/Merge:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'conv2d_10/Sigmoid:0' shape=(?, ?, ?, 1) dtype=float32>]
# ...

# %%
saved_averages
# Out:
# [array([[        nan,  0.        ,  0.        ,  0.        ],
#         [        nan,  0.        ,  0.        ,  0.        ],
#         [        nan,  0.        ,  0.        ,  0.        ],
#         ...,
#         [ 0.00997045,  0.94021393,  0.00219813,  1.        ],
#         [ 0.00523375,  0.96667974,  0.00275927,  1.        ],
#         [ 0.0023385 ,  0.989374  ,  0.43626162,  0.75      ]]),
#  array([[        nan,  0.        ,  0.        ,  0.        ],
#         [        nan,  0.00696325,  0.        ,  0.        ],
#         [        nan,  0.01923183,  0.14285714,  0.07142857],
#         ...,
#         [ 0.08768711,  0.94600903,  0.01634637,  1.        ],
#         [ 0.06019912,  0.95553228,  0.01084956,  1.        ],
#         [ 0.02376616,  0.97596969,  0.00388656,  1.        ]]),
#  array([[        nan,  0.        ,  0.        ,  0.        ],
#         [        nan,  0.04855856,  0.14285714,  0.07142857],
#         [        nan,  0.06224911,  0.14285714,  0.07142857],
# ...

# %%
F1_pix = []
F1_obj = []
R_pix = []
R_obj = []
for num_model in range(len(AM.models)):
    f1_pix = np.zeros([len(saved_averages[0])])
    f1_obj = np.zeros([len(saved_averages[0])])
    r_pix = np.zeros([len(saved_averages[0])])
    r_obj = np.zeros([len(saved_averages[0])])
    for num_threshold in range(len(saved_averages[0])):
        r_pix[num_threshold] = saved_averages[num_model][num_threshold][1]
        r_obj[num_threshold] = saved_averages[num_model][num_threshold][3]
        f1_pix[num_threshold]=2*saved_averages[num_model][num_threshold][0]*saved_averages[num_model][num_threshold][1]/(saved_averages[num_model][num_threshold][0]+saved_averages[num_model][num_threshold][1])
        f1_obj[num_threshold]=2*saved_averages[num_model][num_threshold][3]*saved_averages[num_model][num_threshold][2]/(saved_averages[num_model][num_threshold][3]+saved_averages[num_model][num_threshold][2])
    R_pix.append(r_pix)
    R_obj.append(r_obj)
    F1_obj.append(f1_obj)
    F1_pix.append(f1_pix)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in double_scalars

# %%
number = 1
plt.plot(R_obj[number],F1_obj[number])
plt.grid()
plt.show()

# %%
max_F1_obj_arg = np.zeros([len(AM.models),3])
max_F1_pix_arg = np.zeros([len(AM.models),3])
for num_model in range(len(AM.models)):
    max_F1_obj_arg[num_model,:]=([np.nanargmax(F1_obj[num_model]),F1_obj[num_model][np.nanargmax(F1_obj[num_model])],num_model])
    max_F1_pix_arg[num_model,:]=([np.nanargmax(F1_pix[num_model]),F1_pix[num_model][np.nanargmax(F1_pix[num_model])],num_model])

# %%
print(" The highest F1 score {}\n".format(np.max(max_F1_obj_arg[:,1])))
print(" The highest F1 score model number {}\n".format(np.argmax(max_F1_obj_arg[:,1])))
print(" With threshold value {}".format(np.arange(0.0, 1.0, 0.001)[max_F1_obj_arg[np.argmax(max_F1_obj_arg[:,1]),0].astype(np.int)]))
# Out:
#  The highest F1 score 0.8928571428571429
#
#  The highest F1 score model number 7
#
#  With threshold value 0.06

# %%
np.max(max_F1_pix_arg[:,1])
np.argmax(max_F1_pix_arg[:,1])
# Out:
# 5

# %%
max_F1_obj_arg
# Out:
# array([[  9.99000000e+02,   5.51642591e-01,   0.00000000e+00],
#        [  4.14000000e+02,   7.02902675e-01,   1.00000000e+00],
#        [  1.69000000e+02,   8.13559322e-01,   2.00000000e+00],
#        [  1.17000000e+02,   7.55555556e-01,   3.00000000e+00],
#        [  9.99000000e+02,   7.55555556e-01,   4.00000000e+00],
#        [  2.70000000e+01,   8.87417219e-01,   5.00000000e+00],
#        [  1.20000000e+01,   7.42407199e-01,   6.00000000e+00],
#        [  6.00000000e+01,   8.92857143e-01,   7.00000000e+00],
#        [  1.80000000e+01,   8.15005139e-01,   8.00000000e+00],
#        [  1.00000000e+00,   7.61061947e-01,   9.00000000e+00],
#        [  1.80000000e+01,   7.15727595e-01,   1.00000000e+01],
#        [  6.30000000e+01,   7.21898791e-01,   1.10000000e+01],
#        [  2.35000000e+02,   8.44155844e-01,   1.20000000e+01],
#        [  6.40000000e+01,   8.08133472e-01,   1.30000000e+01],
#        [  4.30000000e+01,   6.07142857e-01,   1.40000000e+01],
# ...

# %%
np.flip(np.argsort(max_F1_obj_arg[:,1]),axis=0)
# Out:
# array([ 7,  5, 12,  8,  2, 13, 16,  9,  4,  3,  6, 11, 10,  1, 15, 14,  0], dtype=int64)

# %%
ordered_max_F1_obj_arg=max_F1_obj_arg[np.flip(np.argsort(max_F1_obj_arg[:,1]),axis=0),:]

# %%
ordered_max_F1_obj_arg
# Out:
# array([[  6.00000000e+01,   8.92857143e-01,   7.00000000e+00],
#        [  2.70000000e+01,   8.87417219e-01,   5.00000000e+00],
#        [  2.35000000e+02,   8.44155844e-01,   1.20000000e+01],
#        [  1.80000000e+01,   8.15005139e-01,   8.00000000e+00],
#        [  1.69000000e+02,   8.13559322e-01,   2.00000000e+00],
#        [  6.40000000e+01,   8.08133472e-01,   1.30000000e+01],
#        [  2.00000000e+00,   7.89625360e-01,   1.60000000e+01],
#        [  1.00000000e+00,   7.61061947e-01,   9.00000000e+00],
#        [  9.99000000e+02,   7.55555556e-01,   4.00000000e+00],
#        [  1.17000000e+02,   7.55555556e-01,   3.00000000e+00],
#        [  1.20000000e+01,   7.42407199e-01,   6.00000000e+00],
#        [  6.30000000e+01,   7.21898791e-01,   1.10000000e+01],
#        [  1.80000000e+01,   7.15727595e-01,   1.00000000e+01],
#        [  4.14000000e+02,   7.02902675e-01,   1.00000000e+00],
#        [  6.70000000e+01,   6.40873016e-01,   1.50000000e+01],
# ...

# %%
AM.models
# Out:
# ['First_Stage BEST  L 1 BT 10 BV 10 E 200 D 1440 MD 1 S 128 HEE 0 HEPI 0 BN 1 DPT 0 DPP 100 .h5',
#  'First_Stage BEST  L 2 BT 10 BV 10 E 100 D 1440 MD 1 S 128 HEE 0 HEPI 0 BN 1 DPT 0 DPP 100 .h5',
#  'First_Stage BEST  L 2 BT 10 BV 10 E 150 D 1440 MD 1 S 128 HEE 0 HEPI 0 BN 1 DPT 0 DPP 100 .h5',
#  'First_Stage BEST  L 3 BT 10 BV 10 E 100 D 1440 MD 1 S 128 HEE 0 HEPI 0 BN 0 DPT 0 DPP 100 .h5',
#  'First_Stage BEST  L 3 BT 10 BV 10 E 100 D 1440 MD 1 S 128 HEE 0 HEPI 0 BN 0 DPT 1 DPP 50 .h5',
#  'First_Stage BEST  L 3 BT 10 BV 10 E 100 D 1440 MD 1 S 128 HEE 0 HEPI 0 BN 1 DPT 0 DPP 100 .h5',
#  'First_Stage BEST  L 3 BT 10 BV 10 E 100 D 1440 MD 1 S 128 HEE 0 HEPI 0 BN 1 DPT 2 DPP 50 .h5',
#  'First_Stage BEST  L 4 BT 10 BV 10 E 100 D 1440 MD 1 S 128 HEE 0 HEPI 0 BN 1 DPT 0 DPP 100 .h5',
#  'First_Stage BEST  L 4 BT 10 BV 10 E 100 D 1440 MD 1 S 128 HEE 0 HEPI 0 BN 1 DPT 2 DPP 50 .h5',
#  'Hard BEST  L 3 BT 10 BV 10 E 60 D 360 MD 0 S 128 HEE 5 HEPI 2 BN 1 DPT 0 DPP 100 .h5',
# ...

# %%
values = ordered_max_F1_obj_arg[:,2].astype(np.int)

# %%
for num in range(len(saved_averages)):
    saved_averages[num] = np.nan_to_num(saved_averages[num])
    F1_obj[num] = np.nan_to_num(F1_obj[num])
    F1_pix[num] = np.nan_to_num(F1_pix[num])

# %%
# F1_pix[5]
saved_averages[5][:,1]
# Out:
# array([ 0.        ,  0.22746816,  0.29782937,  0.31916672,  0.34898549,
#         0.36193012,  0.37800479,  0.38787698,  0.395892  ,  0.40277455,
#         0.41003462,  0.41495723,  0.41950664,  0.43532019,  0.43941118,
#         0.44429314,  0.44778441,  0.45127719,  0.45762484,  0.46030876,
#         0.46857414,  0.47106876,  0.47339769,  0.47604727,  0.47959399,
#         0.48443944,  0.48678876,  0.49778248,  0.49930243,  0.50137045,
#         0.50304743,  0.50524532,  0.5072402 ,  0.50952121,  0.51213971,
#         0.51355762,  0.51428708,  0.51615322,  0.51830796,  0.52068061,
#         0.52247661,  0.52445357,  0.5261862 ,  0.5270652 ,  0.52762956,
#         0.52949061,  0.53064317,  0.53146397,  0.53172343,  0.53276244,
#         0.53335682,  0.53415543,  0.53509263,  0.53607413,  0.53792335,
#         0.53933684,  0.54009642,  0.54116926,  0.54263677,  0.54333953,
#         0.54477486,  0.54600489,  0.5465218 ,  0.54687283,  0.54739865,
# ...

# %%
# Plot pix precision-recall
number = 5
number2 = 6
number3 = 12
number4 = 13
_,model_name = AM.extract_model(number,1)
plt.clf()


plt.plot(saved_averages[number][:,3],F1_obj[number],'-x',linewidth = 3.0,label = 'Baseline')
plt.plot(saved_averages[number2][:,3],F1_obj[number2],'-x',linewidth = 3.0,label = 'Dropout')
# plt.plot(saved_averages[number3][:,3],F1_obj[number3],'-x',linewidth = 3.0, label = 'Hard Examples Batch 2')
# plt.plot(saved_averages[number4][:,3],F1_obj[number4],'-x',linewidth = 3.0,label = 'Hard Examples Batch 3')
legend_properties = {'weight':'bold'}
plt.legend(loc='upper right',bbox_to_anchor=(1.35,1),prop=legend_properties)
plt.xlabel("Average Recall",fontweight = 'bold')
plt.ylabel("F1 Score",fontweight = 'bold')
plt.title("Object F1 Score vs. Recall Curves",fontweight = 'bold')
plt.grid()
plt.savefig('Report Plot/'+model_name+'F1_OBJ_'+'.png')
plt.show()
# Out:
# [<tf.Tensor 'input_18:0' shape=(?, ?, ?, 1) dtype=float32>, <tf.Tensor 'batch_normalization_144/cond/Merge:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'max_pooling2d_33/MaxPool:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'batch_normalization_146/cond/Merge:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'max_pooling2d_34/MaxPool:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'batch_normalization_148/cond/Merge:0' shape=(?, ?, ?, 128) dtype=float32>, <tf.Tensor 'concatenate_33/concat:0' shape=(?, ?, ?, 192) dtype=float32>, <tf.Tensor 'batch_normalization_150/cond/Merge:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'concatenate_34/concat:0' shape=(?, ?, ?, 96) dtype=float32>, <tf.Tensor 'batch_normalization_152/cond/Merge:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'conv2d_190/Sigmoid:0' shape=(?, ?, ?, 1) dtype=float32>]

# %%
# Plot pix precision-recall
number = 5
number2 = 6
number3 = 12
number4 = 13
_,model_name = AM.extract_model(number,1)
plt.clf()
# plt.figure(figsize=(10,5))
plt.plot(saved_averages[number][:,1],saved_averages[number][:,0],'-x',linewidth = 3.0,label = 'No Dropout')
plt.plot(saved_averages[number2][:,1],saved_averages[number2][:,0],'-x',linewidth = 3.0,label = 'Dropout 0.5')
# plt.plot(saved_averages[number3][:,1],saved_averages[number3][:,0],'-x',linewidth = 3.0, label = 'Hard Examples Batch 2')
# plt.plot(saved_averages[number4][:,1],saved_averages[number4][:,0],'-x',linewidth = 3.0,label = 'Hard Examples Batch 3')
legend_properties = {'weight':'bold'}
plt.legend(loc='upper right',bbox_to_anchor=(1.35,1),prop=legend_properties)
plt.xlabel("Average Recall",fontweight = 'bold')
plt.ylabel("Average Precision",fontweight = 'bold')
plt.title("Pixel Average PR Curves",fontweight = 'bold')
plt.grid()
plt.savefig('Report Plot/'+model_name+'PR_PIX_'+'.png')
plt.show()

plt.plot(saved_averages[number][:,3],saved_averages[number][:,2],'-x',linewidth = 3.0,label = 'No Dropout')
plt.plot(saved_averages[number2][:,3],saved_averages[number2][:,2],'-x',linewidth = 3.0,label = 'Dropout 0.5')
# plt.plot(saved_averages[number3][:,3],saved_averages[number3][:,2],'-x',linewidth = 3.0, label = 'Hard Examples Batch 2')
# plt.plot(saved_averages[number4][:,3],saved_averages[number4][:,2],'-x',linewidth = 3.0,label = 'Hard Examples Batch 3')
legend_properties = {'weight':'bold'}
plt.legend(loc='upper right',bbox_to_anchor=(1.55,1),prop=legend_properties)
plt.xlabel("Average Recall",fontweight = 'bold')
plt.ylabel("Average Precision",fontweight = 'bold')
plt.title("Object Average PR Curves",fontweight = 'bold')
plt.grid()
plt.savefig('Report Plot/'+model_name+'PR_OBJ_'+'.png')
plt.show()

plt.plot(saved_averages[number][:,3],F1_obj[number],'-x',linewidth = 3.0,label = 'No Dropout')
plt.plot(saved_averages[number2][:,3],F1_obj[number2],'-x',linewidth = 3.0,label = 'Dropout 0.5')
# plt.plot(saved_averages[number3][:,3],F1_obj[number3],'-x',linewidth = 3.0, label = 'Hard Examples Batch 2')
# plt.plot(saved_averages[number4][:,3],F1_obj[number4],'-x',linewidth = 3.0,label = 'Hard Examples Batch 3')
legend_properties = {'weight':'bold'}
plt.legend(loc='upper right',bbox_to_anchor=(1.35,1),prop=legend_properties)
plt.xlabel("Average Recall",fontweight = 'bold')
plt.ylabel("Average Precision",fontweight = 'bold')
plt.title("Object F1 Score vs. Recall Curves",fontweight = 'bold')
plt.grid()
plt.savefig('Report Plot/'+model_name+'F1_OBJ_'+'.png')
plt.show()

plt.plot(saved_averages[number][:,1],F1_pix[number],'-x',linewidth = 3.0,label = 'No Dropout')
plt.plot(saved_averages[number2][:,1],F1_pix[number2],'-x',linewidth = 3.0,label = 'Dropout 0.5')
# plt.plot(saved_averages[number3][:,1],F1_pix[number3],'-x',linewidth = 3.0, label = 'Hard Examples Batch 2')
# plt.plot(saved_averages[number4][:,1],F1_pix[number4],'-x',linewidth = 3.0,label = 'Hard Examples Batch 3')
legend_properties = {'weight':'bold'}
plt.legend(loc='upper right',bbox_to_anchor=(1.55,1),prop=legend_properties)
plt.xlabel("Average Recall",fontweight = 'bold')
plt.ylabel("Average Precision",fontweight = 'bold')
plt.title("Pixel F1 Score vs. Recall Curves",fontweight = 'bold')
plt.grid()
plt.savefig('Report Plot/'+model_name+'F1_PIX_'+'.png')
plt.show()
# Out:
# [<tf.Tensor 'input_83:0' shape=(?, ?, ?, 1) dtype=float32>, <tf.Tensor 'batch_normalization_486/cond/Merge:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'max_pooling2d_86/MaxPool:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'batch_normalization_488/cond/Merge:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'max_pooling2d_87/MaxPool:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'batch_normalization_490/cond/Merge:0' shape=(?, ?, ?, 128) dtype=float32>, <tf.Tensor 'concatenate_86/concat:0' shape=(?, ?, ?, 192) dtype=float32>, <tf.Tensor 'batch_normalization_492/cond/Merge:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'concatenate_87/concat:0' shape=(?, ?, ?, 96) dtype=float32>, <tf.Tensor 'batch_normalization_494/cond/Merge:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'conv2d_597/Sigmoid:0' shape=(?, ?, ?, 1) dtype=float32>]

# %%
# Plot pix precision-recall
number = 9
number2 = 11
number3 = 12
number4 = 13
_,model_name = AM.extract_model(number,1)
plt.clf()
# plt.figure(figsize=(10,5))
plt.plot(saved_averages[number][:,1],saved_averages[number][:,0],'-x',linewidth = 3.0,label = 'No Hard Examples')
plt.plot(saved_averages[number2][:,1],saved_averages[number2][:,0],'-x',linewidth = 3.0,label = 'Hard Examples Batch 1')
plt.plot(saved_averages[number3][:,1],saved_averages[number3][:,0],'-x',linewidth = 3.0, label = 'Hard Examples Batch 2')
plt.plot(saved_averages[number4][:,1],saved_averages[number4][:,0],'-x',linewidth = 3.0,label = 'Hard Examples Batch 3')
plt.plot(saved_averages[number][np.argmax(F1_obj[number]),1],saved_averages[number][np.argmax(F1_obj[number]),0],'bo'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number2][np.argmax(F1_obj[number2]),1],saved_averages[number2][np.argmax(F1_obj[number2]),0],'yo'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number3][np.argmax(F1_obj[number3]),1],saved_averages[number3][np.argmax(F1_obj[number3]),0],'go'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number4][np.argmax(F1_obj[number4]),1],saved_averages[number4][np.argmax(F1_obj[number4]),0],'ro'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
legend_properties = {'weight':'bold'}
plt.legend(loc='upper right',bbox_to_anchor=(1.55,1),prop=legend_properties)
plt.xlabel("Average Recall",fontweight = 'bold')
plt.ylabel("Average Precision",fontweight = 'bold')
plt.title("Pixel Average PR Curves",fontweight = 'bold')
plt.grid()
plt.savefig('Report Plot/'+model_name+'PR_PIX_'+'.png')
plt.show()

plt.plot(saved_averages[number][:,3],saved_averages[number][:,2],'-x',linewidth = 3.0,label = 'No Hard Examples')
plt.plot(saved_averages[number2][:,3],saved_averages[number2][:,2],'-x',linewidth = 3.0,label = 'Hard Examples Batch 1')
plt.plot(saved_averages[number3][:,3],saved_averages[number3][:,2],'-x',linewidth = 3.0, label = 'Hard Examples Batch 2')
plt.plot(saved_averages[number4][:,3],saved_averages[number4][:,2],'-x',linewidth = 3.0,label = 'Hard Examples Batch 3')

plt.plot(saved_averages[number][np.argmax(F1_obj[number]),3],saved_averages[number][np.argmax(F1_obj[number]),2],'bo'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number2][np.argmax(F1_obj[number2]),3],saved_averages[number2][np.argmax(F1_obj[number2]),2],'yo'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number3][np.argmax(F1_obj[number3]),3],saved_averages[number3][np.argmax(F1_obj[number3]),2],'go'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number4][np.argmax(F1_obj[number4]),3],saved_averages[number4][np.argmax(F1_obj[number4]),2],'ro'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot([0.985,0.1],[0.971,0.289],'ko',label = "Heuristics")
legend_properties = {'weight':'bold'}
plt.legend(loc='upper right',bbox_to_anchor=(1.55,1),prop=legend_properties)
plt.xlabel("Average Recall",fontweight = 'bold')
plt.ylabel("Average Precision",fontweight = 'bold')
plt.title("Object Average PR Curves",fontweight = 'bold')
plt.grid()
plt.savefig('Report Plot/'+model_name+'PR_OBJ_'+'.png')
plt.show()

plt.plot(saved_averages[number][:,3],F1_obj[number],'-x',linewidth = 3.0,label = 'No Hard Examples')
plt.plot(saved_averages[number2][:,3],F1_obj[number2],'-x',linewidth = 3.0,label = 'Hard Examples Batch 1')
plt.plot(saved_averages[number3][:,3],F1_obj[number3],'-x',linewidth = 3.0, label = 'Hard Examples Batch 2')
plt.plot(saved_averages[number4][:,3],F1_obj[number4],'-x',linewidth = 3.0,label = 'Hard Examples Batch 3')
plt.plot(saved_averages[number][np.argmax(F1_obj[number]),3],F1_obj[number][np.argmax(F1_obj[number])],'bo'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number2][np.argmax(F1_obj[number2]),3],F1_obj[number2][np.argmax(F1_obj[number2])],'yo'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number3][np.argmax(F1_obj[number3]),3],F1_obj[number3][np.argmax(F1_obj[number3])],'go'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number4][np.argmax(F1_obj[number4]),3],F1_obj[number4][np.argmax(F1_obj[number4])],'ro'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot([0.985,0.1],[0.978,0.448],'ko',label = "Heuristics")
legend_properties = {'weight':'bold'}
plt.legend(loc='upper right',bbox_to_anchor=(1.55,1),prop=legend_properties)
plt.xlabel("Average Recall",fontweight = 'bold')
plt.ylabel("F1 Score",fontweight = 'bold')
plt.title("Object F1 Score vs. Recall Curves",fontweight = 'bold')
plt.grid()
plt.savefig('Report Plot/'+model_name+'F1_OBJ_'+'.png')
plt.show()

plt.plot(saved_averages[number][:,1],F1_pix[number],'-x',linewidth = 3.0,label = 'No Hard Examples')
plt.plot(saved_averages[number2][:,1],F1_pix[number2],'-x',linewidth = 3.0,label = 'Hard Examples Batch 1')
plt.plot(saved_averages[number3][:,1],F1_pix[number3],'-x',linewidth = 3.0, label = 'Hard Examples Batch 2')
plt.plot(saved_averages[number4][:,1],F1_pix[number4],'-x',linewidth = 3.0,label = 'Hard Examples Batch 3')
plt.plot(saved_averages[number][np.argmax(F1_obj[number]),1],F1_pix[number][np.argmax(F1_obj[number])],'bo'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number2][np.argmax(F1_obj[number2]),1],F1_pix[number2][np.argmax(F1_obj[number2])],'yo'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number3][np.argmax(F1_obj[number3]),1],F1_pix[number3][np.argmax(F1_obj[number3])],'go'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number4][np.argmax(F1_obj[number4]),1],F1_pix[number4][np.argmax(F1_obj[number4])],'ro'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
legend_properties = {'weight':'bold'}
plt.legend(loc='upper right',bbox_to_anchor=(1.55,1),prop=legend_properties)
plt.xlabel("Average Recall",fontweight = 'bold')
plt.ylabel("F1 Score",fontweight = 'bold')
plt.title("Pixel F1 Score vs. Recall Curves",fontweight = 'bold')
plt.grid()
plt.savefig('Report Plot/'+model_name+'F1_PIX_'+'.png')
plt.show()


# plt.plot(saved_averages[number][:,3],saved_averages[number][:,2],'-x',linewidth = 3.0)
# plt.xlabel("Average Recall")
# plt.ylabel("Average Precision")
# plt.title("Object Precision Recall Level 1")
# plt.grid()
# plt.savefig('Report Plot/'+model_name+'PR_OBJ_'+'.png')
# plt.show()

# plt.plot(saved_averages[number][:,3],saved_averages[number][:,2],'-x',linewidth = 3.0)
# plt.xlabel("Average Recall")
# plt.ylabel("Average Precision")
# plt.title("Object Precision Recall Level 1")
# plt.grid()
# plt.savefig('Report Plot/'+model_name+'PR_OBJ_'+'.png')
# plt.show()

# plt.clf()
# Plot object precision-recall
# plt.plot(average_total_measurements[:,3],average_total_measurements[:,2],'-x',linewidth = 3.0)
# plt.xlabel("Average Recall")
# plt.ylabel("Average Precision")
# plt.grid()
# plt.savefig('PR plots/PR object/'+'PR_OBJ_'+model_name+'.png')
# plt.clf()
# # Plot F-score
# f_score_pix = 2*np.divide(np.multiply(average_total_measurements[:,0],average_total_measurements[:,1]),average_total_measurements[:,0]+average_total_measurements[:,1])
# plt.plot(average_total_measurements[:,1],f_score_pix,'-x')
# plt.ylabel("F1 Score")
# plt.xlabel("Average Recall")
# plt.grid()
# plt.savefig('PR plots/F1/'+'F1_'+model_name+'.png')
# plt.clf()
# Out:
# [<tf.Tensor 'input_54:0' shape=(?, ?, ?, 1) dtype=float32>, <tf.Tensor 'batch_normalization_264/cond/Merge:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'max_pooling2d_45/MaxPool:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'batch_normalization_266/cond/Merge:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'max_pooling2d_46/MaxPool:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'batch_normalization_268/cond/Merge:0' shape=(?, ?, ?, 128) dtype=float32>, <tf.Tensor 'concatenate_45/concat:0' shape=(?, ?, ?, 192) dtype=float32>, <tf.Tensor 'batch_normalization_270/cond/Merge:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'concatenate_46/concat:0' shape=(?, ?, ?, 96) dtype=float32>, <tf.Tensor 'batch_normalization_272/cond/Merge:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'conv2d_346/Sigmoid:0' shape=(?, ?, ?, 1) dtype=float32>]

# %%
# Plot pix precision-recall
number = 0
number2 = 2
number3 = 5
number4 = 7
_,model_name = AM.extract_model(number,1)
plt.clf()
plt.plot(saved_averages[number][:,3],saved_averages[number][:,2],'-x',linewidth = 3.0,label = 'Level 1')

plt.plot(saved_averages[number2][:,3],saved_averages[number2][:,2],'-x',linewidth = 3.0,label = 'Level 2')

plt.plot(saved_averages[number3][:,3],saved_averages[number3][:,2],'-x',linewidth = 3.0, label = 'Level 3')
plt.plot(saved_averages[number4][:,3],saved_averages[number4][:,2],'-x',linewidth = 3.0,label = 'Level 4')



plt.plot(saved_averages[number][np.argmax(F1_obj[number]),3],saved_averages[number][np.argmax(F1_obj[number]),2],'bo'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number2][np.argmax(F1_obj[number2]),3],saved_averages[number2][np.argmax(F1_obj[number2]),2],'yo'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number3][np.argmax(F1_obj[number3]),3],saved_averages[number3][np.argmax(F1_obj[number3]),2],'go'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number4][np.argmax(F1_obj[number4]),3],saved_averages[number4][np.argmax(F1_obj[number4]),2],'ro'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot([0.985,0.1],[0.971,0.289],'ko',label = "Heuristics")
legend_properties = {'weight':'bold'}
plt.legend(loc='upper right',bbox_to_anchor=(1.3,1),prop=legend_properties)
plt.xlabel("Average Recall",fontweight = 'bold')
plt.ylabel("Average Precision",fontweight = 'bold')
plt.title("Object Average PR Curves",fontweight = 'bold')
plt.grid()
plt.savefig('Report Plot/'+model_name+'PR_OBJ_'+'.png')
plt.show()

###########################################


plt.plot(saved_averages[number][:,1],saved_averages[number][:,0],'-x',linewidth = 3.0,label = 'Level 1')

plt.plot(saved_averages[number2][:,1],saved_averages[number2][:,0],'-x',linewidth = 3.0,label = 'Level 2')

plt.plot(saved_averages[number3][:,1],saved_averages[number3][:,0],'-x',linewidth = 3.0, label = 'Level 3')
plt.plot(saved_averages[number4][:,1],saved_averages[number4][:,0],'-x',linewidth = 3.0,label = 'Level 4')


plt.plot(saved_averages[number][np.argmax(F1_obj[number]),1],saved_averages[number][np.argmax(F1_obj[number]),0],'bo'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number2][np.argmax(F1_obj[number2]),1],saved_averages[number2][np.argmax(F1_obj[number2]),0],'yo'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number3][np.argmax(F1_obj[number3]),1],saved_averages[number3][np.argmax(F1_obj[number3]),0],'go'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number4][np.argmax(F1_obj[number4]),1],saved_averages[number4][np.argmax(F1_obj[number4]),0],'ro'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')



legend_properties = {'weight':'bold'}
plt.legend(loc='upper right',bbox_to_anchor=(1.3,1),prop=legend_properties)
plt.xlabel("Average Recall",fontweight = 'bold')
plt.ylabel("Average Precision",fontweight = 'bold')
plt.title("Pixel Average PR Curves",fontweight = 'bold')
plt.grid()
plt.savefig('Report Plot/'+model_name+'PR_PIX_'+'.png')
plt.show()


plt.plot(saved_averages[number][:,3],F1_obj[number],'-x',linewidth = 3.0,label = 'Level 1')
plt.plot(saved_averages[number2][:,3],F1_obj[number2],'-x',linewidth = 3.0,label = 'Level 2')
plt.plot(saved_averages[number3][:,3],F1_obj[number3],'-x',linewidth = 3.0, label = 'Level 3')
plt.plot(saved_averages[number4][:,3],F1_obj[number4],'-x',linewidth = 3.0,label = 'Level 4')


plt.plot(saved_averages[number][np.argmax(F1_obj[number]),3],F1_obj[number][np.argmax(F1_obj[number])],'bo'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number2][np.argmax(F1_obj[number2]),3],F1_obj[number2][np.argmax(F1_obj[number2])],'yo'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number3][np.argmax(F1_obj[number3]),3],F1_obj[number3][np.argmax(F1_obj[number3])],'go'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number4][np.argmax(F1_obj[number4]),3],F1_obj[number4][np.argmax(F1_obj[number4])],'ro'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot([0.985,0.1],[0.978,0.448],'ko',label = "Heuristics")
legend_properties = {'weight':'bold'}
plt.legend(loc='upper right',bbox_to_anchor=(1.3,1),prop=legend_properties)
plt.xlabel("Average Recall",fontweight = 'bold')
plt.ylabel("F1 Score",fontweight = 'bold')
plt.title("Object F1 Score vs. Recall Curves",fontweight = 'bold')
plt.grid()
plt.savefig('Report Plot/'+model_name+'F1_OBJ_'+'.png')
plt.show()
###########################################################################################3
plt.plot(saved_averages[number][:,1],F1_pix[number],'-x',linewidth = 3.0,label = 'Level 1')
plt.plot(saved_averages[number2][:,1],F1_pix[number2],'-x',linewidth = 3.0,label = 'Level 2')
plt.plot(saved_averages[number3][:,1],F1_pix[number3],'-x',linewidth = 3.0, label = 'Level 3')
plt.plot(saved_averages[number4][:,1],F1_pix[number4],'-x',linewidth = 3.0,label = 'Level 4')



plt.plot(saved_averages[number][np.argmax(F1_obj[number]),1],F1_pix[number][np.argmax(F1_obj[number])],'bo'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number2][np.argmax(F1_obj[number2]),1],F1_pix[number2][np.argmax(F1_obj[number2])],'yo'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number3][np.argmax(F1_obj[number3]),1],F1_pix[number3][np.argmax(F1_obj[number3])],'go'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')
plt.plot(saved_averages[number4][np.argmax(F1_obj[number4]),1],F1_pix[number4][np.argmax(F1_obj[number4])],'ro'
         ,markeredgewidth = 1.5,markersize = 7,markeredgecolor = 'k')


legend_properties = {'weight':'bold'}
plt.legend(loc='upper right',bbox_to_anchor=(1.3,1),prop=legend_properties)
plt.xlabel("Average Recall",fontweight = 'bold')
plt.ylabel("F1 Score",fontweight = 'bold')
plt.title("Pixel F1 Score vs. Recall Curves",fontweight = 'bold')
plt.grid()
plt.savefig('Report Plot/'+model_name+'F1_PIX_'+'.png')
plt.show()
# Out:
# [<tf.Tensor 'input_59:0' shape=(?, ?, ?, 1) dtype=float32>, <tf.Tensor 'batch_normalization_282/cond/Merge:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'conv2d_361/Sigmoid:0' shape=(?, ?, ?, 1) dtype=float32>]

# %%
2*0.971*0.985/(0.971+0.985)
# Out:
# 0.9779498977505112
