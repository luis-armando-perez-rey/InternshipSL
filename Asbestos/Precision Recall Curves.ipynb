# %% [markdown]
# # Precision Recall Curves

# %%
from DataAsbestos import DataAsbestos
from AsbestosModels import AsbestosModels
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Get the data

# %% [markdown]
# #### Complete Data Set

# %%
path_data = "./Complete Data Set"
DA_parameters = {'path_name':path_data,
                 'data_name':'Final_Report',
                 'size':128,
                 'data_augmentation':False,
                 'train_percentage':0.63,
                 'val_percentage':0.07,
                 'test_percentage':0.3,
                 'file_type_load':'.jpg',
                 'removal':True}
DA = DataAsbestos(**DA_parameters)
# Out:
# The data set already exists. Loading the specified data ...
#
# Cropped data already exists. Obtaining the names from the cropped images
# Total of training crops = 0
#
# Total of validation crops = 448
#
# Total of test crops = 448

# %% [markdown]
# #### Preprocessed Data Set

# %%
path_data = "./Complete Data Preprocessed"
DA_parameters = {'path_name':path_data,
                 'data_name':'Final_Report',
                 'size':128,
                 'data_augmentation':False,
                 'train_percentage':0.63,
                 'val_percentage':0.07,
                 'test_percentage':0.3,
                 'file_type_load':'.jpg',
                 'removal':True}
DA = DataAsbestos(**DA_parameters)
# Out:
# The data set already exists. Loading the specified data ...
#
# Cropped data already exists. Obtaining the names from the cropped images
# Total of training crops = 0
#
# Total of validation crops = 448
#
# Total of test crops = 448

# %% [markdown]
# #### Thick Data Set

# %%
path_data = "./Complete Data Set Thick"
DA_parameters = {'path_name':path_data,
                 'data_name':'Final_Report',
                 'size':128,
                 'data_augmentation':False,
                 'train_percentage':0.63,
                 'val_percentage':0.07,
                 'test_percentage':0.3,
                 'file_type_load':'.jpg',
                 'removal':True}
DA = DataAsbestos(**DA_parameters)
# Out:
# The data set already exists. Loading the specified data ...
#
# Cropped data already exists. Obtaining the names from the cropped images
# Total of training crops = 0
#
# Total of validation crops = 448
#
# Total of test crops = 448

# %% [markdown]
# ### Get the models

# %%
AM = AsbestosModels('./Final_Report/Models')
model,model_name = AM.extract_model(0,1)
# Out:
# Model number 0 : First_Stage BEST   : parameters {'D': 1440, 'E': 200, 'MD': 1, 'DPT': 0, 'BV': 10, 'HEE': 0, 'BN': 1, 'BT': 10, 'HEPI': 0, 'L': 1, 'S': 128, 'DPP': 100}
# Model number 1 : First_Stage BEST   : parameters {'D': 1440, 'E': 100, 'MD': 1, 'DPT': 0, 'BV': 10, 'HEE': 0, 'BN': 1, 'BT': 10, 'HEPI': 0, 'L': 2, 'S': 128, 'DPP': 100}
# Model number 2 : First_Stage BEST   : parameters {'D': 1440, 'E': 150, 'MD': 1, 'DPT': 0, 'BV': 10, 'HEE': 0, 'BN': 1, 'BT': 10, 'HEPI': 0, 'L': 2, 'S': 128, 'DPP': 100}
# Model number 3 : First_Stage BEST   : parameters {'D': 1440, 'E': 100, 'MD': 1, 'DPT': 0, 'BV': 10, 'HEE': 0, 'BN': 0, 'BT': 10, 'HEPI': 0, 'L': 3, 'S': 128, 'DPP': 100}
# Model number 4 : First_Stage BEST   : parameters {'D': 1440, 'E': 100, 'MD': 1, 'DPT': 1, 'BV': 10, 'HEE': 0, 'BN': 0, 'BT': 10, 'HEPI': 0, 'L': 3, 'S': 128, 'DPP': 50}
# Model number 5 : First_Stage BEST   : parameters {'D': 1440, 'E': 100, 'MD': 1, 'DPT': 0, 'BV': 10, 'HEE': 0, 'BN': 1, 'BT': 10, 'HEPI': 0, 'L': 3, 'S': 128, 'DPP': 100}
# Model number 6 : First_Stage BEST   : parameters {'D': 1440, 'E': 100, 'MD': 1, 'DPT': 2, 'BV': 10, 'HEE': 0, 'BN': 1, 'BT': 10, 'HEPI': 0, 'L': 3, 'S': 128, 'DPP': 50}
# Model number 7 : First_Stage BEST   : parameters {'D': 1440, 'E': 100, 'MD': 1, 'DPT': 0, 'BV': 10, 'HEE': 0, 'BN': 1, 'BT': 10, 'HEPI': 0, 'L': 4, 'S': 128, 'DPP': 100}
# Model number 8 : First_Stage BEST   : parameters {'D': 1440, 'E': 100, 'MD': 1, 'DPT': 2, 'BV': 10, 'HEE': 0, 'BN': 1, 'BT': 10, 'HEPI': 0, 'L': 4, 'S': 128, 'DPP': 50}
# Model number 9 : Hard BEST   : parameters {'D': 360, 'E': 60, 'MD': 0, 'DPT': 0, 'BV': 10, 'HEE': 5, 'BN': 1, 'BT': 10, 'HEPI': 2, 'L': 3, 'S': 128, 'DPP': 100}
# Model number 10 : Hard BEST   : parameters {'D': 376, 'E': 60, 'MD': 0, 'DPT': 0, 'BV': 10, 'HEE': 1, 'BN': 1, 'BT': 10, 'HEPI': 2, 'L': 3, 'S': 128, 'DPP': 100}
# Model number 11 : HardHE0 BEST   : parameters {'D': 506, 'E': 60, 'MD': 0, 'DPT': 0, 'BV': 10, 'HEE': 5, 'BN': 1, 'BT': 10, 'HEPI': 2, 'L': 3, 'S': 128, 'DPP': 100}
# Model number 12 : HardHE1 BEST   : parameters {'D': 652, 'E': 60, 'MD': 0, 'DPT': 0, 'BV': 10, 'HEE': 5, 'BN': 1, 'BT': 10, 'HEPI': 2, 'L': 3, 'S': 128, 'DPP': 100}
# Model number 13 : HardHE2 BEST   : parameters {'D': 798, 'E': 60, 'MD': 0, 'DPT': 0, 'BV': 10, 'HEE': 5, 'BN': 1, 'BT': 10, 'HEPI': 2, 'L': 3, 'S': 128, 'DPP': 100}
# Model number 14 : Preprocessed BEST   : parameters {'D': 360, 'E': 60, 'MD': 0, 'DPT': 0, 'BV': 10, 'HEE': 1, 'BN': 1, 'BT': 10, 'HEPI': 2, 'L': 3, 'S': 128, 'DPP': 100}
# Model number 15 : PreprocessedHE0 BEST   : parameters {'D': 506, 'E': 60, 'MD': 0, 'DPT': 0, 'BV': 10, 'HEE': 1, 'BN': 1, 'BT': 10, 'HEPI': 2, 'L': 3, 'S': 128, 'DPP': 100}
# Model number 16 : ThickHardHE0 BEST   : parameters {'D': 522, 'E': 60, 'MD': 0, 'DPT': 0, 'BV': 10, 'HEE': 1, 'BN': 1, 'BT': 10, 'HEPI': 2, 'L': 3, 'S': 128, 'DPP': 100}
# [<tf.Tensor 'input_1:0' shape=(?, ?, ?, 1) dtype=float32>, <tf.Tensor 'batch_normalization_2/cond/Merge:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'conv2d_3/Sigmoid:0' shape=(?, ?, ?, 1) dtype=float32>]

# %% [markdown]
# ### Loop over models

# %%
DA.val_names
# Out:
# ['Tile_r006_c007.jpg',
#  'Tile_r002_c007.jpg',
#  'Tile_r002_c000.jpg',
#  'Tile_r003_c002.jpg',
#  'DarkTile_r002_c005.jpg',
#  'DarkTile_r001_c000.jpg',
#  'DarkTile_r003_c002.jpg']

# %%
avg_total_measurements
# Out:
# array([[        nan,  0.        ,  0.        ,  0.        ],
#        [        nan,  0.08298106,  0.28571429,  0.10714286],
#        [        nan,  0.09395405,  0.28571429,  0.10714286],
#        ...,
#        [ 0.08036308,  0.94579739,  0.02415321,  1.        ],
#        [ 0.06102625,  0.95294415,  0.01726123,  1.        ],
#        [ 0.03768484,  0.96736034,  0.01057128,  1.        ]])

# %%
import numpy as np
import Asbestos_Utils as AU
import cv2
import matplotlib.pyplot as plt
percentage = 0.2
threshold_range = np.arange(0.0, 1.0, 0.001)
names = DA.val_names
for num_model in range(16,17):
    model,model_name = AM.extract_model(num_model,1)
    avg_precision_recall_parameters= {'names':names,
                                      'threshold_range':threshold_range,
                                      'percentage':percentage,
                                      'model':model}
    average_total_measurements = avg_precision_recall(**avg_precision_recall_parameters)
    np.save('./Numpy Variables/'+'Validation data '+'Percentage'+str(percentage).replace('.','_')+model_name,average_total_measurements)
    save_plots(average_total_measurements,model_name)
# Out:
# [<tf.Tensor 'input_3:0' shape=(?, ?, ?, 1) dtype=float32>, <tf.Tensor 'batch_normalization_14/cond/Merge:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'max_pooling2d_3/MaxPool:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'batch_normalization_16/cond/Merge:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'max_pooling2d_4/MaxPool:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'batch_normalization_18/cond/Merge:0' shape=(?, ?, ?, 128) dtype=float32>, <tf.Tensor 'concatenate_3/concat:0' shape=(?, ?, ?, 192) dtype=float32>, <tf.Tensor 'batch_normalization_20/cond/Merge:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'concatenate_4/concat:0' shape=(?, ?, ?, 96) dtype=float32>, <tf.Tensor 'batch_normalization_22/cond/Merge:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'conv2d_25/Sigmoid:0' shape=(?, ?, ?, 1) dtype=float32>]
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:229: RuntimeWarning: invalid value encountered in long_scalars
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 2530 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 1 ...
#
# 	 0 out of 1102 pixels were found: 0%
#
# Fiber not found
#
# 0
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 643 out of 2530 pixels were found: 25%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 337 out of 1102 pixels were found: 30%
#
# Fiber found
#
# 2
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 699 out of 2530 pixels were found: 27%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 370 out of 1102 pixels were found: 33%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 738 out of 2530 pixels were found: 29%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 401 out of 1102 pixels were found: 36%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 766 out of 2530 pixels were found: 30%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 417 out of 1102 pixels were found: 37%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 784 out of 2530 pixels were found: 30%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 427 out of 1102 pixels were found: 38%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 803 out of 2530 pixels were found: 31%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 435 out of 1102 pixels were found: 39%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 812 out of 2530 pixels were found: 32%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 449 out of 1102 pixels were found: 40%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 822 out of 2530 pixels were found: 32%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 453 out of 1102 pixels were found: 41%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 832 out of 2530 pixels were found: 32%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 461 out of 1102 pixels were found: 41%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 843 out of 2530 pixels were found: 33%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 466 out of 1102 pixels were found: 42%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 857 out of 2530 pixels were found: 33%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 472 out of 1102 pixels were found: 42%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 900 out of 2530 pixels were found: 35%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 474 out of 1102 pixels were found: 43%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 906 out of 2530 pixels were found: 35%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 480 out of 1102 pixels were found: 43%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 912 out of 2530 pixels were found: 36%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 486 out of 1102 pixels were found: 44%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 924 out of 2530 pixels were found: 36%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 488 out of 1102 pixels were found: 44%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 932 out of 2530 pixels were found: 36%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 490 out of 1102 pixels were found: 44%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 938 out of 2530 pixels were found: 37%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 493 out of 1102 pixels were found: 44%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 943 out of 2530 pixels were found: 37%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 496 out of 1102 pixels were found: 45%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 950 out of 2530 pixels were found: 37%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 500 out of 1102 pixels were found: 45%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 959 out of 2530 pixels were found: 37%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 503 out of 1102 pixels were found: 45%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 967 out of 2530 pixels were found: 38%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 508 out of 1102 pixels were found: 46%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 971 out of 2530 pixels were found: 38%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 508 out of 1102 pixels were found: 46%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 976 out of 2530 pixels were found: 38%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 511 out of 1102 pixels were found: 46%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 980 out of 2530 pixels were found: 38%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 514 out of 1102 pixels were found: 46%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 986 out of 2530 pixels were found: 38%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 519 out of 1102 pixels were found: 47%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 987 out of 2530 pixels were found: 39%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 521 out of 1102 pixels were found: 47%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 993 out of 2530 pixels were found: 39%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 522 out of 1102 pixels were found: 47%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 999 out of 2530 pixels were found: 39%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 525 out of 1102 pixels were found: 47%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1000 out of 2530 pixels were found: 39%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 526 out of 1102 pixels were found: 47%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1003 out of 2530 pixels were found: 39%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 530 out of 1102 pixels were found: 48%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1010 out of 2530 pixels were found: 39%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 530 out of 1102 pixels were found: 48%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1016 out of 2530 pixels were found: 40%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 533 out of 1102 pixels were found: 48%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1018 out of 2530 pixels were found: 40%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 533 out of 1102 pixels were found: 48%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1018 out of 2530 pixels were found: 40%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 534 out of 1102 pixels were found: 48%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1022 out of 2530 pixels were found: 40%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 535 out of 1102 pixels were found: 48%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1026 out of 2530 pixels were found: 40%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 536 out of 1102 pixels were found: 48%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1032 out of 2530 pixels were found: 40%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 538 out of 1102 pixels were found: 48%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1034 out of 2530 pixels were found: 40%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 540 out of 1102 pixels were found: 49%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1041 out of 2530 pixels were found: 41%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 542 out of 1102 pixels were found: 49%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1043 out of 2530 pixels were found: 41%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 547 out of 1102 pixels were found: 49%
#
# Fiber found
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1045 out of 2530 pixels were found: 41%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 549 out of 1102 pixels were found: 49%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1049 out of 2530 pixels were found: 41%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 550 out of 1102 pixels were found: 49%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1052 out of 2530 pixels were found: 41%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 550 out of 1102 pixels were found: 49%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1054 out of 2530 pixels were found: 41%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 550 out of 1102 pixels were found: 49%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1054 out of 2530 pixels were found: 41%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 551 out of 1102 pixels were found: 50%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1058 out of 2530 pixels were found: 41%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 553 out of 1102 pixels were found: 50%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1061 out of 2530 pixels were found: 41%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 554 out of 1102 pixels were found: 50%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1064 out of 2530 pixels were found: 42%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 554 out of 1102 pixels were found: 50%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1065 out of 2530 pixels were found: 42%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 554 out of 1102 pixels were found: 50%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1066 out of 2530 pixels were found: 42%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 555 out of 1102 pixels were found: 50%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1069 out of 2530 pixels were found: 42%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 557 out of 1102 pixels were found: 50%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1071 out of 2530 pixels were found: 42%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 558 out of 1102 pixels were found: 50%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1072 out of 2530 pixels were found: 42%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 559 out of 1102 pixels were found: 50%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1074 out of 2530 pixels were found: 42%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 559 out of 1102 pixels were found: 50%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1076 out of 2530 pixels were found: 42%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 560 out of 1102 pixels were found: 50%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1078 out of 2530 pixels were found: 42%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 561 out of 1102 pixels were found: 50%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1079 out of 2530 pixels were found: 42%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 563 out of 1102 pixels were found: 51%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1082 out of 2530 pixels were found: 42%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 565 out of 1102 pixels were found: 51%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1082 out of 2530 pixels were found: 42%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 566 out of 1102 pixels were found: 51%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1085 out of 2530 pixels were found: 42%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 566 out of 1102 pixels were found: 51%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1087 out of 2530 pixels were found: 42%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 566 out of 1102 pixels were found: 51%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1089 out of 2530 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 566 out of 1102 pixels were found: 51%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1089 out of 2530 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 568 out of 1102 pixels were found: 51%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1089 out of 2530 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 569 out of 1102 pixels were found: 51%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1092 out of 2530 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 570 out of 1102 pixels were found: 51%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1092 out of 2530 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 570 out of 1102 pixels were found: 51%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1093 out of 2530 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 571 out of 1102 pixels were found: 51%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1095 out of 2530 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 571 out of 1102 pixels were found: 51%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1097 out of 2530 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 572 out of 1102 pixels were found: 51%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1101 out of 2530 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 573 out of 1102 pixels were found: 51%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1103 out of 2530 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 574 out of 1102 pixels were found: 52%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1103 out of 2530 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 574 out of 1102 pixels were found: 52%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1104 out of 2530 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 574 out of 1102 pixels were found: 52%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1104 out of 2530 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 575 out of 1102 pixels were found: 52%
#
# Fiber found
#
# 3
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1106 out of 2530 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 575 out of 1102 pixels were found: 52%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1109 out of 2530 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 577 out of 1102 pixels were found: 52%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1109 out of 2530 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 579 out of 1102 pixels were found: 52%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1110 out of 2530 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 580 out of 1102 pixels were found: 52%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1112 out of 2530 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 581 out of 1102 pixels were found: 52%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1113 out of 2530 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 581 out of 1102 pixels were found: 52%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1116 out of 2530 pixels were found: 44%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 581 out of 1102 pixels were found: 52%
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1117 out of 2530 pixels were found: 44%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 583 out of 1102 pixels were found: 52%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1120 out of 2530 pixels were found: 44%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 584 out of 1102 pixels were found: 52%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1121 out of 2530 pixels were found: 44%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 584 out of 1102 pixels were found: 52%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1122 out of 2530 pixels were found: 44%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 585 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1122 out of 2530 pixels were found: 44%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 587 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1125 out of 2530 pixels were found: 44%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 587 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1127 out of 2530 pixels were found: 44%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 588 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1128 out of 2530 pixels were found: 44%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 588 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1129 out of 2530 pixels were found: 44%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 588 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1131 out of 2530 pixels were found: 44%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 588 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1131 out of 2530 pixels were found: 44%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 589 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1133 out of 2530 pixels were found: 44%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 590 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1134 out of 2530 pixels were found: 44%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 590 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1135 out of 2530 pixels were found: 44%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 591 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1136 out of 2530 pixels were found: 44%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 591 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1138 out of 2530 pixels were found: 44%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 591 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1138 out of 2530 pixels were found: 44%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 591 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1141 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 591 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1141 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 593 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1141 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 593 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1142 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 593 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1143 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 593 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1145 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 594 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1146 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 594 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1147 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 594 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1147 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 594 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1149 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 594 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1151 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 594 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1151 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 595 out of 1102 pixels were found: 53%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1151 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 596 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1153 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 596 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1154 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 596 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1155 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 596 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1155 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 598 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1156 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 599 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1157 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 599 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1158 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 600 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1160 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 600 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1160 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 601 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1163 out of 2530 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 603 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1165 out of 2530 pixels were found: 46%
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 603 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1166 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 604 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1166 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 604 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1166 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 604 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1167 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 604 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1169 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 605 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1173 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 605 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1175 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 605 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1175 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 605 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1175 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 605 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1177 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 605 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1178 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 606 out of 1102 pixels were found: 54%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1178 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 607 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1178 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 608 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1178 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 608 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1180 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 608 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1180 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 609 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1180 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 609 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1181 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 609 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1182 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 610 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1184 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 610 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1184 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 610 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1185 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 610 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1186 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 611 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1187 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 611 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1188 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 611 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1189 out of 2530 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 611 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1191 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 611 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1191 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 613 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1194 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 613 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1197 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 614 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1198 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 614 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1199 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 614 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1199 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 614 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1201 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 614 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1202 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 614 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1203 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 616 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1203 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 616 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1204 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 616 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1205 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 616 out of 1102 pixels were found: 55%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1205 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 617 out of 1102 pixels were found: 55%
#
# Fiber found
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1206 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 618 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1206 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 618 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1207 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 618 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1208 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 618 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1209 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 618 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1211 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 618 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1211 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 618 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1211 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 618 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1212 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 618 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1212 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 619 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1212 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 619 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1212 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 619 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1213 out of 2530 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 619 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1215 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 619 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1215 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 619 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1215 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 619 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1216 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 619 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1216 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 619 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1217 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 620 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1217 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 620 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1217 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 620 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1219 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 620 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1219 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 620 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1220 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 620 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1221 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 620 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1221 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 620 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1222 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 620 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1222 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 620 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1223 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 620 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1224 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 620 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1224 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 620 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1224 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 620 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1224 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 621 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1226 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 621 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1226 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 622 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1226 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 622 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1226 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 622 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1228 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 622 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1228 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 622 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1228 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 622 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1228 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 623 out of 1102 pixels were found: 56%
#
# Fiber found
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1228 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 623 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1229 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 623 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1231 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 623 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1231 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 624 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1231 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 624 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1232 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 625 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1233 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 625 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1234 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 625 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1235 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 626 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1235 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 626 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1236 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 626 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1236 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 626 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1237 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 626 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1238 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 626 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1238 out of 2530 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 626 out of 1102 pixels were found: 56%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1240 out of 2530 pixels were found: 49%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 653 out of 1102 pixels were found: 59%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1240 out of 2530 pixels were found: 49%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 653 out of 1102 pixels were found: 59%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1240 out of 2530 pixels were found: 49%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 653 out of 1102 pixels were found: 59%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1240 out of 2530 pixels were found: 49%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 653 out of 1102 pixels were found: 59%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1240 out of 2530 pixels were found: 49%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 654 out of 1102 pixels were found: 59%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1241 out of 2530 pixels were found: 49%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 654 out of 1102 pixels were found: 59%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1241 out of 2530 pixels were found: 49%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 655 out of 1102 pixels were found: 59%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1241 out of 2530 pixels were found: 49%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 656 out of 1102 pixels were found: 59%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1243 out of 2530 pixels were found: 49%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 656 out of 1102 pixels were found: 59%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1244 out of 2530 pixels were found: 49%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 657 out of 1102 pixels were found: 59%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1244 out of 2530 pixels were found: 49%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 657 out of 1102 pixels were found: 59%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1244 out of 2530 pixels were found: 49%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 657 out of 1102 pixels were found: 59%
#
# Fiber found
#
# 4
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1245 out of 2530 pixels were found: 49%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1683 out of 2159 pixels were found: 77%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3375 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 20
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1684 out of 2159 pixels were found: 77%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3375 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 20
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1684 out of 2159 pixels were found: 77%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3375 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 20
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1686 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3376 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 20
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1687 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3376 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 20
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1687 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3376 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 20
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1687 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3376 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 20
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1688 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3376 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 20
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1688 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3376 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 20
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1690 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3376 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 20
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1690 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3376 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 20
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1690 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3376 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 20
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1690 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3376 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 20
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1690 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3377 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 20
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1692 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3377 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 21
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1692 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3378 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 21
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1693 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3379 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 21
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1693 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3380 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 21
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1695 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3380 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 21
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1696 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3380 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 21
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1696 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3381 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 21
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1696 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3381 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 21
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1696 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3382 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 21
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1696 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3382 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 21
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1697 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3382 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 21
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1697 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3382 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 21
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1699 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3382 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 21
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1699 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3382 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 21
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1699 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3382 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 21
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1700 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3382 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 22
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1702 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3382 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 22
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1702 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3382 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 22
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1703 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3382 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 22
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1705 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3382 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 22
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1705 out of 2159 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3382 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 22
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1706 out of 2159 pixels were found: 79%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3382 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 22
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1706 out of 2159 pixels were found: 79%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3382 out of 3391 pixels were found: 99%
#
# Fiber found
# 22
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1707 out of 2159 pixels were found: 79%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3382 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 22
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1709 out of 2159 pixels were found: 79%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3382 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 22
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1710 out of 2159 pixels were found: 79%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3383 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 22
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1710 out of 2159 pixels were found: 79%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3383 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 23
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1712 out of 2159 pixels were found: 79%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3383 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 24
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1713 out of 2159 pixels were found: 79%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3383 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 24
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1714 out of 2159 pixels were found: 79%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3383 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 25
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1716 out of 2159 pixels were found: 79%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3383 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 25
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1717 out of 2159 pixels were found: 79%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3383 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 25
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1718 out of 2159 pixels were found: 79%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3384 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 25
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1720 out of 2159 pixels were found: 79%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3384 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 25
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1723 out of 2159 pixels were found: 79%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3384 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 25
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1723 out of 2159 pixels were found: 79%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3384 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 25
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1725 out of 2159 pixels were found: 79%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3384 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 25
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1727 out of 2159 pixels were found: 79%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3384 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 25
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1731 out of 2159 pixels were found: 80%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3384 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 25
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1737 out of 2159 pixels were found: 80%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3385 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 25
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1739 out of 2159 pixels were found: 80%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3385 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 26
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1741 out of 2159 pixels were found: 80%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3385 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 26
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1743 out of 2159 pixels were found: 80%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3385 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 26
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1747 out of 2159 pixels were found: 80%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3386 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 26
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1749 out of 2159 pixels were found: 81%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3386 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 27
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1754 out of 2159 pixels were found: 81%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3387 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 27
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1756 out of 2159 pixels were found: 81%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3388 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 27
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1757 out of 2159 pixels were found: 81%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3388 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 27
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1765 out of 2159 pixels were found: 81%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3388 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 27
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1771 out of 2159 pixels were found: 82%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3388 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 27
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1777 out of 2159 pixels were found: 82%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3388 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 29
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1786 out of 2159 pixels were found: 82%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3388 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 31
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1805 out of 2159 pixels were found: 83%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3388 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 31
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1813 out of 2159 pixels were found: 83%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3389 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 33
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1821 out of 2159 pixels were found: 84%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3390 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 35
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1831 out of 2159 pixels were found: 84%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3390 out of 3391 pixels were found: 99%
#
# Fiber found
#
# 48
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1851 out of 2159 pixels were found: 85%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3391 out of 3391 pixels were found: 100%
#
# Fiber found
#
# 60
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1867 out of 2159 pixels were found: 86%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3391 out of 3391 pixels were found: 100%
#
# Fiber found
#
# 78
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1908 out of 2159 pixels were found: 88%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3391 out of 3391 pixels were found: 100%
#
# Fiber found
#
# 117
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1997 out of 2159 pixels were found: 92%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 3391 out of 3391 pixels were found: 100%
#
# Fiber found
#
# 457
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-3248c08879b0> in <module>()
#      14     average_total_measurements = avg_precision_recall(**avg_precision_recall_parameters)
#      15     np.save('./Numpy Variables/'+'Validation data '+'Percentage'+str(percentage).replace('.','_')+model_name,average_total_measurements)
# ---> 16     save_plots(average_total_measurements,model_name)
#
# NameError: name 'save_plots' is not defined

# %% [markdown]
# # Test data evaluation

# %%
len(np.array([0]))
# Out:
# 1

# %%
import numpy as np
import Asbestos_Utils as AU
import cv2
import matplotlib.pyplot as plt
percentage = 0.2
threshold_range =np.array([0.064]) 
names = DA.test_names
for num_model in [13]:
    model,model_name = AM.extract_model(num_model,1)
    avg_precision_recall_parameters= {'names':names,
                                      'threshold_range':threshold_range,
                                      'percentage':percentage,
                                      'model':model}
    average_total_measurements = avg_precision_recall(**avg_precision_recall_parameters)
    np.save('./Numpy Variables/'+'Test data '+'Percentage'+str(percentage).replace('.','_')+model_name,average_total_measurements)
#     save_plots(average_total_measurements,model_name)
# Out:
# [<tf.Tensor 'input_12:0' shape=(?, ?, ?, 1) dtype=float32>, <tf.Tensor 'batch_normalization_72/cond/Merge:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'max_pooling2d_13/MaxPool:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'batch_normalization_74/cond/Merge:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'max_pooling2d_14/MaxPool:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'batch_normalization_76/cond/Merge:0' shape=(?, ?, ?, 128) dtype=float32>, <tf.Tensor 'concatenate_13/concat:0' shape=(?, ?, ?, 192) dtype=float32>, <tf.Tensor 'batch_normalization_78/cond/Merge:0' shape=(?, ?, ?, 64) dtype=float32>, <tf.Tensor 'concatenate_14/concat:0' shape=(?, ?, ?, 96) dtype=float32>, <tf.Tensor 'batch_normalization_80/cond/Merge:0' shape=(?, ?, ?, 32) dtype=float32>, <tf.Tensor 'conv2d_92/Sigmoid:0' shape=(?, ?, ?, 1) dtype=float32>]
# Analyzing image Tile_r002_c005.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 233 out of 353 pixels were found: 66%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 160 out of 264 pixels were found: 60%
#
# Fiber found
#
# 0
# Analyzing image Tile_r000_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 126 out of 326 pixels were found: 38%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 192 out of 477 pixels were found: 40%
#
# Fiber found
#
# 0
# Analyzing image Tile_r006_c003.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 746 out of 1518 pixels were found: 49%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 672 out of 1129 pixels were found: 59%
#
# Fiber found
#
# 	 Analyzing fiber 2 ...
#
# 	 3308 out of 6001 pixels were found: 55%
#
# Fiber found
#
# 	 Analyzing fiber 3 ...
#
# 	 292 out of 474 pixels were found: 61%
#
# Fiber found
#
# 	 Analyzing fiber 4 ...
#
# 	 49 out of 59 pixels were found: 83%
#
# Fiber found
#
# 1
# Analyzing image Tile_r008_c006.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 72 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 1 ...
#
# 	 92 out of 851 pixels were found: 10%
#
# Fiber not found
#
# 	 Analyzing fiber 2 ...
#
# 	 102 out of 152 pixels were found: 67%
#
# Fiber found
#
# 	 Analyzing fiber 3 ...
#
# 	 51 out of 62 pixels were found: 82%
#
# Fiber found
#
# 0
# Analyzing image Tile_r001_c005.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 382 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 1 ...
#
# 	 344 out of 601 pixels were found: 57%
#
# Fiber found
#
# 	 Analyzing fiber 2 ...
#
# 	 2152 out of 4189 pixels were found: 51%
#
# Fiber found
#
# 0
# Analyzing image Tile_r000_c003.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 6 out of 58 pixels were found: 10%
#
# Fiber not found
#
# 	 Analyzing fiber 1 ...
#
# 	 1121 out of 26660 pixels were found: 4%
#
# Fiber not found
#
# 0
# Analyzing image Tile_r004_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 213 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 1 ...
#
# 	 46 out of 559 pixels were found: 8%
#
# Fiber not found
#
# 2
# Analyzing image Tile_r002_c006.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 1170 out of 2287 pixels were found: 51%
#
# Fiber found
#
# 0
# Analyzing image Tile_r007_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 199 out of 407 pixels were found: 48%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 41 out of 107 pixels were found: 38%
#
# Fiber found
#
# 0
# Analyzing image Tile_r000_c006.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 145 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 1 ...
#
# 	 133 out of 313 pixels were found: 42%
#
# Fiber found
#
# 	 Analyzing fiber 2 ...
#
# 	 234 out of 512 pixels were found: 45%
#
# Fiber found
#
# 	 Analyzing fiber 3 ...
#
# 	 321 out of 680 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 4 ...
#
# 	 149 out of 321 pixels were found: 46%
#
# Fiber found
#
# 0
# Analyzing image Tile_r003_c000.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 3381 out of 5978 pixels were found: 56%
#
# Fiber found
#
# 0
# Analyzing image Tile_r004_c008.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 121 out of 196 pixels were found: 61%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 46 out of 171 pixels were found: 26%
#
# Fiber found
#
# 0
# Analyzing image Tile_r004_c004.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 420 out of 770 pixels were found: 54%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 1932 out of 4151 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 2 ...
#
# 	 233 out of 340 pixels were found: 68%
#
# Fiber found
#
# 2
# Analyzing image Tile_r004_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 90 out of 143 pixels were found: 62%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 0 out of 88 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 2 ...
#
# 	 65 out of 122 pixels were found: 53%
#
# Fiber found
#
# 1
# Analyzing image Tile_r007_c006.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 171 out of 577 pixels were found: 29%
#
# Fiber found
#
# 0
# Analyzing image Tile_r008_c005.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 71 out of 93 pixels were found: 76%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 103 out of 241 pixels were found: 42%
#
# Fiber found
#
# 	 Analyzing fiber 2 ...
#
# 	 676 out of 1826 pixels were found: 37%
#
# Fiber found
#
# 	 Analyzing fiber 3 ...
#
# 	 208 out of 518 pixels were found: 40%
#
# Fiber found
#
# 	 Analyzing fiber 4 ...
#
# 	 72 out of 207 pixels were found: 34%
#
# Fiber found
#
# 	 Analyzing fiber 5 ...
#
# 	 494 out of 756 pixels were found: 65%
#
# Fiber found
#
# 0
# Analyzing image Tile_r008_c004.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 208 out of 330 pixels were found: 63%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 419 out of 665 pixels were found: 63%
#
# Fiber found
#
# 	 Analyzing fiber 2 ...
#
# 	 948 out of 1434 pixels were found: 66%
#
# Fiber found
#
# 	 Analyzing fiber 3 ...
#
# 	 689 out of 1778 pixels were found: 38%
#
# Fiber found
#
# 	 Analyzing fiber 4 ...
#
# 	 247 out of 451 pixels were found: 54%
#
# Fiber found
#
# 	 Analyzing fiber 5 ...
#
# 	 601 out of 1233 pixels were found: 48%
#
# Fiber found
#
# 1
# Analyzing image Tile_r005_c001.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 106 out of 172 pixels were found: 61%
#
# Fiber found
#
# 1
# Analyzing image Tile_r006_c009.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 642 out of 1372 pixels were found: 46%
#
# Fiber found
#
# 1
# Analyzing image Tile_r006_c001.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 195 out of 306 pixels were found: 63%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 84 out of 289 pixels were found: 29%
#
# Fiber found
#
# 2
# Analyzing image DarkTile_r003_c005.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 83 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 1 ...
#
# 	 216 out of 313 pixels were found: 69%
#
# Fiber found
#
# 0
# Analyzing image DarkTile_r000_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 120 out of 200 pixels were found: 60%
#
# Fiber found
#
# 1
# Analyzing image DarkTile_r004_c001.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 213 out of 487 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 31 out of 72 pixels were found: 43%
#
# Fiber found
#
# 	 Analyzing fiber 2 ...
#
# 	 0 out of 249 pixels were found: 0%
#
# Fiber not found
#
# 0
# Analyzing image DarkTile_r001_c008.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 53 out of 172 pixels were found: 30%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 252 out of 397 pixels were found: 63%
#
# Fiber found
#
# 	 Analyzing fiber 2 ...
#
# 	 923 out of 1630 pixels were found: 56%
#
# Fiber found
#
# 0
# Analyzing image DarkTile_r003_c006.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 67 out of 128 pixels were found: 52%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 0 out of 62 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 2 ...
#
# 	 0 out of 24 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 3 ...
#
# 	 0 out of 30 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 4 ...
#
# 	 0 out of 42 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 5 ...
#
# 	 238 out of 540 pixels were found: 44%
#
# Fiber found
#
# 	 Analyzing fiber 6 ...
#
# 	 134 out of 205 pixels were found: 65%
#
# Fiber found
#
# 1
# Analyzing image DarkTile_r002_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 186 out of 245 pixels were found: 75%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 91 out of 150 pixels were found: 60%
#
# Fiber found
#
# 0
# Analyzing image DarkTile_r006_c001.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 84 out of 125 pixels were found: 67%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 92 out of 317 pixels were found: 29%
#
# Fiber found
#
# 1
# Analyzing image DarkTile_r005_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 72 out of 126 pixels were found: 57%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 174 out of 372 pixels were found: 46%
#
# Fiber found
#
# 	 Analyzing fiber 2 ...
#
# 	 275 out of 902 pixels were found: 30%
#
# Fiber found
#
# 	 Analyzing fiber 3 ...
#
# 	 0 out of 144 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 4 ...
# 	 1341 out of 2209 pixels were found: 60%
#
# Fiber found
#
# 	 Analyzing fiber 5 ...
#
# 	 314 out of 398 pixels were found: 78%
#
# Fiber found
#
# 	 Analyzing fiber 6 ...
#
# 	 404 out of 604 pixels were found: 66%
#
# Fiber found
#
# 0
# Analyzing image DarkTile_r006_c005.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 41 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 1 ...
#
# 	 0 out of 30 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 2 ...
#
# 	 804 out of 1196 pixels were found: 67%
#
# Fiber found
#
# 	 Analyzing fiber 3 ...
#
# 	 131 out of 232 pixels were found: 56%
#
# Fiber found
#
# 0
# Analyzing image DarkTile_r003_c001.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 223 out of 407 pixels were found: 54%
#
# Fiber found
#
# 1
# Analyzing image DarkTile_r000_c008.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 263 out of 536 pixels were found: 49%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 132 out of 235 pixels were found: 56%
#
# Fiber found
#
# 	 Analyzing fiber 2 ...
#
# 	 86 out of 132 pixels were found: 65%
#
# Fiber found
#
# 0
# Analyzing image DarkTile_r005_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 68 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 1 ...
#
# 	 69 out of 118 pixels were found: 58%
#
# Fiber found
#
# 	 Analyzing fiber 2 ...
#
# 	 513 out of 861 pixels were found: 59%
#
# Fiber found
#
# 	 Analyzing fiber 3 ...
#
# 	 0 out of 206 pixels were found: 0%
#
# Fiber not found
#
# 4

# %%
average_total_measurements
# Out:
# array([[ 0.83533552,  0.47300968,  0.78772321,  0.81517857]])

# %%
average_total_measurements[0][0]*average_total_measurements[0][1]*2/(average_total_measurements[0][0]+average_total_measurements[0][1])
# Out:
# 0.60400235024028215

# %%
average_total_measurements[0][2]*average_total_measurements[0][3]*2/(average_total_measurements[0][2]+average_total_measurements[0][3])
# Out:
# 0.80121575785306454

# %%
def save_plots(average_total_measurements,model_name):
    # Plot pix precision-recall
    plt.plot(average_total_measurements[:,1],average_total_measurements[:,0],'-x',linewidth = 3.0)
    plt.xlabel("Average Recall")
    plt.ylabel("Average Precision")
    plt.grid()
    plt.savefig('PR plots/PR pix/'+'PR_PIX_'+model_name+'.png')
    plt.clf()
    # Plot object precision-recall
    plt.plot(average_total_measurements[:,3],average_total_measurements[:,2],'-x',linewidth = 3.0)
    plt.xlabel("Average Recall")
    plt.ylabel("Average Precision")
    plt.grid()
    plt.savefig('PR plots/PR object/'+'PR_OBJ_'+model_name+'.png')
    plt.clf()
    # Plot F-score
    f_score_pix = 2*np.divide(np.multiply(average_total_measurements[:,0],average_total_measurements[:,1]),average_total_measurements[:,0]+average_total_measurements[:,1])
    plt.plot(average_total_measurements[:,1],f_score_pix,'-x')
    plt.ylabel("F1 Score")
    plt.xlabel("Average Recall")
    plt.grid()
    plt.savefig('PR plots/F1/'+'F1_'+model_name+'.png')
    plt.clf()

# %%
threshold = [0.2,0.3,0.4]
percentage = 0.2
prediction_parameters= {'name':test_names[0],
                       'image':image,
                       'label':label,
                       'contours_label':contour,
                       'model':model,
                       'threshold_range':threshold,
                       'percentage':percentage}
Pred = Prediction(**prediction_parameters)
# Out:
# Analyzing image Tile_r002_c005.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 399 out of 986 pixels were found: 40%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 1582 out of 1675 pixels were found: 94%
#
# Fiber found
#
# 3
# Analyzing image Tile_r002_c005.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 442 out of 986 pixels were found: 44%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 1618 out of 1675 pixels were found: 96%
#
# Fiber found
#
# 3
# Analyzing image Tile_r002_c005.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 471 out of 986 pixels were found: 47%
#
# Fiber found
#
# 	 Analyzing fiber 1 ...
#
# 	 1642 out of 1675 pixels were found: 98%
#
# Fiber found
#
# 8

# %%
avg_precision_recall(validation_names,[0.1,0.2],0.1,model)
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:229: RuntimeWarning: invalid value encountered in long_scalars
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 1648 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 1 ...
#
# 	 0 out of 566 pixels were found: 0%
#
# Fiber not found
#
# 0
# Analyzing image Tile_r006_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 1648 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 1 ...
#
# 	 0 out of 566 pixels were found: 0%
#
# Fiber not found
#
# 0
# Analyzing image Tile_r002_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 652 pixels were found: 0%
#
# Fiber not found
#
# 0
# Analyzing image Tile_r002_c007.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 652 pixels were found: 0%
#
# Fiber not found
#
# 0
# Analyzing image Tile_r002_c000.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 355 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 1 ...
#
# 	 0 out of 1166 pixels were found: 0%
#
# Fiber not found
#
# 0
# Analyzing image Tile_r002_c000.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 355 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 1 ...
#
# 	 0 out of 1166 pixels were found: 0%
#
# Fiber not found
#
# 0
# Analyzing image Tile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 213 pixels were found: 0%
#
# Fiber not found
#
# 0
# Analyzing image Tile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 213 pixels were found: 0%
#
# Fiber not found
#
# 0
# Analyzing image DarkTile_r002_c005.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 141 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 1 ...
#
# 	 0 out of 160 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 2 ...
#
# 	 0 out of 107 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 3 ...
#
# 	 0 out of 220 pixels were found: 0%
#
# Fiber not found
#
# 0
# Analyzing image DarkTile_r002_c005.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 141 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 1 ...
#
# 	 0 out of 160 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 2 ...
#
# 	 0 out of 107 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 3 ...
#
# 	 0 out of 220 pixels were found: 0%
#
# Fiber not found
#
# 0
# Analyzing image DarkTile_r001_c000.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 48 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 1 ...
#
# 	 0 out of 766 pixels were found: 0%
#
# Fiber not found
#
# 0
# Analyzing image DarkTile_r001_c000.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 48 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 1 ...
#
# 	 0 out of 766 pixels were found: 0%
#
# Fiber not found
#
# 0
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 986 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 1 ...
#
# 	 0 out of 1675 pixels were found: 0%
#
# Fiber not found
#
# 0
# Analyzing image DarkTile_r003_c002.jpg ...
#
# 	 Analyzing fiber 0 ...
#
# 	 0 out of 986 pixels were found: 0%
#
# Fiber not found
#
# 	 Analyzing fiber 1 ...
#
# 	 0 out of 1675 pixels were found: 0%
#
# Fiber not found
#
# 0
# array([[ nan,   0.,   0.,   0.],
#        [ nan,   0.,   0.,   0.]])

# %%
import numpy as np
def avg_precision_recall(names,threshold_range,percentage,model):
    total_measurements = np.zeros([len(threshold_range),4])
    total_object_count = np.zeros([len(threshold_range),3]) 
    total_pixel_count = np.zeros([len(threshold_range),3])
    for name in names:
        image = AU.load_image(path_data,name)
        label = AU.load_image(path_data,name.replace(AU.get_file_extension(name),'_FIB'+AU.get_file_extension(name)))
        contour = get_contours(label)
        prediction_parameters= {'name':name,
                           'image':image,
                           'label':label,
                           'contours_label':contour,
                           'model':model,
                           'threshold_range':threshold_range,
                           'percentage':percentage}
        predictionObj = Prediction(**prediction_parameters)
        total_pixel_count = total_pixel_count+predictionObj.pixel_count
        total_object_count = total_object_count+predictionObj.object_count
        total_measurements = total_measurements+predictionObj.measurements
    average_total_measurements = total_measurements/len(names)
    return average_total_measurements

def get_contours(image, invert = True):
    """
    A function that obtains the contours from an image
    :return: A list with the contours for an image
    """
    image = image.astype(np.uint8)
    if invert:
        __, thresh = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY_INV)
        __, contours_per_image, __ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    else:
        __, thresh = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)
        __, contours_per_image, __ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

    return contours_per_image
class Prediction(object):
    def __init__(self, name, image, label, contours_label, model, threshold_range, percentage):
        self.name = name
        self.image = image
        self.label = label
        self.size = image.shape[0]
        self.contours_label = contours_label
        self.total_fibers = len(contours_label)
        self.model = model
        self.threshold_range = threshold_range
        self.percentage = percentage
        prediction_model_unprocessed = self.prediction_model()
        self.measurements = np.zeros([len(threshold_range),4])
        self.pixel_count = np.zeros([len(threshold_range),3])
        self.object_count = np.zeros([len(threshold_range),3])
        for num_theta,theta in enumerate(threshold_range):
            prediction_theta = self.post_processing(theta,prediction_model_unprocessed)
            prediction_contours = get_contours(prediction_theta)
            tp_pix,fp_pix,fn_pix,pixel_precision,pixel_recall = self.pixel_statistics(prediction_theta)
            true_positive_objects,false_positive_objects,false_negative_objects = self.fiber_identification(prediction_contours)
            object_precision,object_recall = self.object_statistics(true_positive_objects,false_positive_objects,false_negative_objects)
            self.measurements[num_theta,0] = pixel_precision
            self.measurements[num_theta,1] = pixel_recall
            self.measurements[num_theta,2] = object_precision
            self.measurements[num_theta,3] = object_recall
            self.pixel_count[num_theta,0] = tp_pix
            self.pixel_count[num_theta,1] = fp_pix
            self.pixel_count[num_theta,2] = fn_pix
            self.object_count[num_theta,0] = true_positive_objects
            self.object_count[num_theta,1] = false_positive_objects
            self.object_count[num_theta,2] = false_negative_objects
            
    def object_statistics(self,true_positive_objects,false_positive_objects,false_negative_objects):
        try:
            object_precision = true_positive_objects / (true_positive_objects + false_positive_objects)
        except ZeroDivisionError:
            object_precision = 0
        try:
            object_recall = true_positive_objects/(self.total_fibers)
        except ZeroDivisionError:
            object_recall = 0
        return object_precision,object_recall

    def fiber_identification(self,prediction_contours):
        """
        Function that identifies the fibers in an image
        :return: found_fibers(number) The amount of fibers found in the image
        image_percentages(array) an array that includes the percentage found for each fiber
        image_fiber_pixels(array) an array that includes the amount of pixels for each fiber
        image_intersection_pixels(array) an array that includes the amount of pixels found for each fiber
        """
        # Initialize the outputs
        fiber_contours = get_contours(self.label)
        found_fibers = 0
        image_percentages = []
        image_fiber_pixels = []
        image_intersection_pixels = []
        # Produce a mask for prediction comparizon
        black_mask_prediction = np.zeros((self.size, self.size))
        black_mask_prediction = cv2.drawContours(black_mask_prediction, prediction_contours, -1, 255, -1)
        print("Analyzing image %s ...\n" % self.name)
        # Analyze whether each of the fibers in the image has been found and how much of the fiber was
        # identified
        for num_fiber, fiber in enumerate(fiber_contours):
            print("\t Analyzing fiber %d ...\n" % num_fiber)

            found_fiber, percentage_found, intersection_pixels, fiber_pixels = self.fiber_discriminator(
                fiber, black_mask_prediction)
            # Remove the identified fiber from the prediction
            black_mask_prediction = self.remove_fiber_from_prediction(fiber, black_mask_prediction)
            # Include the results for each fiber in the overall output
            found_fibers += found_fiber
            image_intersection_pixels.append(intersection_pixels)
            image_fiber_pixels.append(fiber_pixels)
        false_positive_amount = self.false_positive_object_count(black_mask_prediction)
        print(false_positive_amount)
        false_negative_objects = len(fiber_contours)-found_fibers
        return found_fibers, false_positive_amount,false_negative_objects

    def false_positive_object_count(self,black_mask_prediction):
        """
        Counts the number of false positive objects in the prediction
        :param black_mask_prediction: The mask without the fiber predictions
        :return: The number of false positive objects found
        """
        false_positive_contours = get_contours(black_mask_prediction,invert = False)
        return len(false_positive_contours)



    def fiber_discriminator(self, fiber, black_mask_prediction):
        """
        Function that takes the contours of a fiber and tells whether the fiber was identified by the prediction
        with respect to certain percentage threshold.
        :param fiber: Contour for the fiber
        :param black_mask_prediction: Prediction mask to compare with
        :return: found_fibers(number) Either 1 (found) or 0 (not found)
        percentage_found Percentage of correctly identified pixels
        fiber_pixels The amount of pixels for each fiber
        intersection_pixels The amount of pixels found by the prediction for each fiber
        """
        # Create a mask for the fiber
        mask_label = np.zeros((self.size, self.size))
        mask_label = cv2.drawContours(mask_label, [fiber], -1, 255, -1)

        fiber_pixels = int(np.sum(mask_label) / 255)  # Count of the fiber pixels
        # Compare the fiber mask with the prediction
        comparison = np.zeros((self.size, self.size))
        cv2.bitwise_and(mask_label, black_mask_prediction, comparison)
        intersection_pixels = int(np.sum(comparison) / 255)  # Count pixels in the intersection
        percentage_found = intersection_pixels / fiber_pixels  # Percentage of fiber pixels identified
        print("\t %d out of %d pixels were found: %d%%\n" % (
        intersection_pixels, fiber_pixels, percentage_found * 100))
        # Identify if a fiber was trully found
        if percentage_found >= self.percentage:
            found_fiber = 1
            print("Fiber found\n")
        else:
            found_fiber = 0
            print("Fiber not found\n")
        # Remove the analyzed fiber pixels from the prediction (for False Positive purposes)

        return found_fiber, percentage_found * 100, intersection_pixels, fiber_pixels

    def remove_fiber_from_prediction(self, fiber, black_mask_prediction):
        """
        This function removes from the prediction mask the pixels which predict certain fiber.
        :param fiber: The fiber contour that will be removed from the prediction mask
        :param black_mask_prediction: The prediction mask
        :return: Returns the modified prediction mask without the selected fiber pixels.
        """
        # Draw the fiber over the black prediction mask
        black_mask_prediction = cv2.drawContours(black_mask_prediction, [fiber], -1, 255, -1)
        # Create a fiber comparison mask
        fiber_mask = np.zeros((self.size, self.size))
        fiber_mask = cv2.drawContours(fiber_mask, [fiber], -1, 255, -1)
        # Get the contours of this new mask
        new_contours = get_contours(black_mask_prediction,invert= False)
        max_contour_intersection = 0 # Define an initial amount of pixels for the comparison
        num_contour_removal = 0 # Choose the first new contour as the one that will be removed
        comparison2 = np.zeros((self.size,self.size))
        for num_contour, contour in enumerate(new_contours):
            # Create a mask for the comparison between the new contours and the fiber
            black_mask_new = np.zeros((self.size, self.size))
            black_mask_new = cv2.drawContours(black_mask_new, [contour], -1, 255, -1)
            intersection = np.sum(cv2.bitwise_and(black_mask_new, fiber_mask, comparison2))
            if intersection > max_contour_intersection:
                max_contour_intersection = intersection
                num_contour_removal = num_contour
        black_mask_prediction = cv2.drawContours(black_mask_prediction, new_contours, num_contour_removal, 0, -1)
        return black_mask_prediction

  
    
    def prediction_model(self):
        prediction_model_unprocessed = self.model.predict(self.image.reshape(1, self.size, self.size, 1)).reshape(self.size,self.size)
        return prediction_model_unprocessed
    
    def post_processing(self,threshold,prediction_unprocessed):
        prediction_bool_unprocessed = (prediction_unprocessed >= threshold)
        prediction_grayscale = prediction_bool_unprocessed * 255
        prediction_processed = self.remove_trash(prediction_grayscale)
        return prediction_processed
    
        

    def remove_trash(self, prediction_unprocessed):
        """
        This function takes a prediction along with its contours and returns an image without small isolated pixels
        :return: ndarray with the prediction striped out of small isolated pixels
        """
        contours_preprocessed = get_contours(prediction_unprocessed)
        for num_contour, contour in enumerate(contours_preprocessed):
            if int(cv2.contourArea(contour)) <= 18:
                prediction_unprocessed = cv2.drawContours(prediction_unprocessed, [contour], -1, 255, -1)
        prediction_processed = prediction_unprocessed
        return prediction_processed

    def pixel_statistics(self,prediction_theta):
        """
        The input is a prediction image and a labeled image. The image matrices should be 0 where there is a fiber
        :param prediction: Image prediction with 0 if there is a fiber (can be boolean or not as long as this requirement is added)
        :return: Pixel values for TP,FP,FN. Precision and recall for the prediction is also returned.
        """
        tp_mask = np.logical_not((prediction_theta == 0) * (self.label == 0)) * 1
        fp_mask = np.logical_not((prediction_theta == 0) * (self.label != 0)) * 1
        fn_mask = np.logical_not((prediction_theta != 0) * (self.label == 0)) * 1
        tp_pix = np.sum(np.logical_not(tp_mask))
        fp_pix = np.sum(np.logical_not(fp_mask))
        fn_pix = np.sum(np.logical_not(fn_mask))
        try:
            pixel_precision = tp_pix / (tp_pix + fp_pix)
        except ZeroDivisionError:
            pixel_precision = 0
        try:
            pixel_recall = tp_pix / (tp_pix + fn_pix)
        except ZeroDivisionError:
            pixel_recall = 0
        return tp_pix,fp_pix,fn_pix,pixel_precision, pixel_recall
